# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_benin  = pd.read_csv('/home/nibruad/Documents/Data Sets/data (1)/data/benin-malanville.csv')
data_sierraleones = pd.read_csv('/home/nibruad/Documents/Data Sets/data (1)/data/sierraleone-bumbuna.csv')
data_togo = pd.read_csv('/home/nibruad/Documents/Data Sets/data (1)/data/togo-dapaong_qc.csv')

# %% [markdown]
# # Calculate Summary Statistics

# %% [markdown]
# # benin-malanville

# %%
data_benin.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      240.559452     167.187516     115.358961     236.589496
# std       331.131327     261.710501     158.691074     326.894859
# min       -12.900000      -7.800000     -12.600000       0.000000
# 25%        -2.000000      -0.500000      -2.100000       0.000000
# 50%         1.800000      -0.100000       1.600000       4.500000
# 75%       483.400000     314.200000     216.300000     463.700000
# max      1413.000000     952.300000     759.200000    1342.300000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.883576      28.179683      54.487969       2.121113
# std       316.536515       5.924297      28.073069       1.603466
# min         0.000000      11.000000       2.100000       0.000000
# ...

# %% [markdown]
# # sierraleone-bumbuna

# %%
data_sierraleones.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# ...

# %% [markdown]
# # togo-dapaong

# %%
data_togo.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      230.555040     151.258469     116.444352     226.144375
# std       322.532347     250.956962     156.520714     317.346938
# min       -12.700000       0.000000       0.000000       0.000000
# 25%        -2.200000       0.000000       0.000000       0.000000
# 50%         2.100000       0.000000       2.500000       4.400000
# 75%       442.400000     246.400000     215.700000     422.525000
# max      1424.000000    1004.500000     805.700000    1380.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      219.568588      27.751788      55.013160       2.368093
# std       307.932510       4.758023      28.778732       1.462668
# min         0.000000      14.900000       3.300000       0.000000
# ...

# %% [markdown]
# # Data Quality Check

# %% [markdown]
# # Check for Missing Value

# %%
  # Benin dataset
mis_val_1 = data_benin.isnull().sum()
print("Missing Values in Benin Dataset:")
print(mis_val_1)

# Sierra Leone dataset
mis_val_2 = data_sierraleones.isnull().sum()
print("\nMissing Values in Sierra Leone Dataset:")
print(mis_val_2)

# Togo dataset
mis_val_3 = data_togo.isnull().sum()
print("\nMissing Values in Togo Dataset:")
print(mis_val_3)
# Out:
# Missing Values in Benin Dataset:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64
#
# Missing Values in Sierra Leone Dataset:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# ...

# %% [markdown]
# # Data Quality Check

# %% [markdown]
# # Check for Missing Values

# %%
# Benin dataset
benin_missing = data_benin.isnull().sum()
print("Missing Values in Benin Dataset:")
print(benin_missing)

# Sierra Leone dataset
sierraleones_missing = data_sierraleones.isnull().sum()
print("\nMissing Values in Sierra Leone Dataset:")
print(sierraleones_missing)

# Togo dataset
togo_missing = data_togo.isnull().sum()
print("\nMissing Values in Togo Dataset:")
print(togo_missing)
# Out:
# Missing Values in Benin Dataset:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64
#
# Missing Values in Sierra Leone Dataset:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# ...

# %% [markdown]
# # Incorrect Entries (Negative Values)

# %%
# Benin dataset
neg_ghi = data_benin[data_benin['GHI'] <0]['GHI'].count()
print("Negative GHI values in Benin:", neg_ghi)


neg_dni =data_benin[data_benin['DNI'] <0]['DNI'].count()
print("Negative DNI values in Benin:", neg_dni)


neg_dhi =data_benin[data_benin['DHI'] <0]['DHI'].count()
print("Negative DHI values in Benin:", neg_dhi)
# Out:
# Negative GHI values in Benin: 258847
# Negative DNI values in Benin: 275987
# Negative DHI values in Benin: 259182

# %%
# Sierra Leone dataset

neg_ghi = data_sierraleones[data_sierraleones['GHI'] <0]['GHI'].count()
print("Negative GHI values in Sierra Leone:", neg_ghi)

neg_dni =data_sierraleones[data_sierraleones['DNI'] <0]['DNI'].count()
print("Negative DNI values in Sierra Leone:", neg_dni)

neg_dhi = data_sierraleones[data_sierraleones['DHI'] <0]['DHI'].count()
print("Negative DHI values in Sierra Leone:", neg_dhi)
# Out:
# Negative GHI values in Sierra Leone: 261135
# Negative DNI values in Sierra Leone: 266352
# Negative DHI values in Sierra Leone: 263128

# %%
# Togo dataset
neg_ghi = data_togo[data_togo['GHI'] <0]['GHI'].count()
print("Negative GHI values in Togo:", neg_ghi)

neg_dni =data_togo[data_togo['DNI'] <0]['DNI'].count()
print("Negative DNI values in Togo:", neg_dni)

neg_dhi = data_togo[data_togo['DHI'] <0]['DHI'].count()
print("Negative DHI values in Togo:", neg_dhi)
# Out:
# Negative GHI values in Togo: 257385
# Negative DNI values in Togo: 0
# Negative DHI values in Togo: 0

# %% [markdown]
# # Check for Outliers using Box Plots:

# %%
datasets = [data_benin, data_sierraleones, data_togo]  

dataset_names = ['Benin', 'Sierra Leone', 'Togo']  

columns = ['ModA', 'ModB', 'WS', 'WSgust']  


for i, dataset in enumerate(datasets):  
    # Loop through each specified column in the current dataset
    for column in columns:  
       
        plt.figure(figsize=(8, 6))  
       
        plt.boxplot(dataset[column], showfliers=True)  
      
        plt.title(f'Box Plot of {column} ({dataset_names[i]})')  
      
        plt.ylabel(f'{column} Values')  
     
        plt.show()  

        # Access and print the outlier data points
        outliers = [flier.get_ydata() for flier in plt.boxplot(dataset[column], showfliers=True)['fliers']]

# %% [markdown]
# # Time Series Plots for GHI, DNI, DHI, and Tamb:

# %%
datasets = [data_benin, data_sierraleones, data_togo]
dataset_names = ['Benin', 'Sierra Leone', 'Togo']

for dataset in datasets:
    dataset['Date'] = pd.to_datetime(dataset['Timestamp'])

# Function to plot time series data
def plot_time_series(dataset, column, title):
    plt.figure(figsize=(12, 6))
    plt.plot(dataset['Date'], dataset[column])
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.grid(True)
    plt.show()

# Plot GHI, DNI, DHI, and Tamb for each dataset
columns = ['GHI', 'DNI', 'DHI', 'Tamb']
for i, dataset in enumerate(datasets):
    for column in columns:
        plot_time_series(dataset, column, f'{column} Time Series - {dataset_names[i]}')

# Evaluating Cleaning Impact on ModA and ModB
for i, dataset in enumerate(datasets):
    cleaned_data = dataset[dataset['Cleaning'] == 1]
    uncleaned_data = dataset[dataset['Cleaning'] == 0]

    for column in ['ModA', 'ModB']:
        plt.figure(figsize=(12, 6))
        plt.plot(cleaned_data['Date'], cleaned_data[column], label='Cleaned')
        plt.plot(uncleaned_data['Date'], uncleaned_data[column], label='Uncleaned')
        plt.title(f'{column} Time Series - {dataset_names[i]} (Cleaning Impact)')
        plt.xlabel('Date')
        plt.ylabel(column)
        plt.legend()
        plt.grid(True)
        plt.show()

# %% [markdown]
# # Evaluating Cleaning Impact on ModA and ModB

# %%
datasets = [data_benin, data_sierraleones, data_togo]
dataset_names = ['Benin', 'Sierra Leone', 'Togo']

for i, dataset in enumerate(datasets):
    # Assuming 'Cleaning' column has values 0 (no cleaning) and 1 (cleaning)
    cleaned_data = dataset[dataset['Cleaning'] == 1]
    uncleaned_data = dataset[dataset['Cleaning'] == 0]
    
    # Convert 'Date' column to datetime if necessary
    cleaned_data['Date'] = pd.to_datetime(cleaned_data['Date'])
    uncleaned_data['Date'] = pd.to_datetime(uncleaned_data['Date'])

    for column in ['ModA', 'ModB']:
        plt.figure(figsize=(12, 6))
        plt.plot(cleaned_data['Date'], cleaned_data[column], label='Cleaned')
        plt.plot(uncleaned_data['Date'], uncleaned_data[column], label='Uncleaned', alpha=0.6)  # Added alpha for better visibility
        plt.title(f'{column} Time Series - {dataset_names[i]} (Cleaning Impact)')
        plt.xlabel('Date')
        plt.ylabel(column)
        plt.legend()
        plt.grid(True)
        plt.show()
# Out:
# /tmp/ipykernel_4773/1607970373.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['Date'] = pd.to_datetime(cleaned_data['Date'])
# /tmp/ipykernel_4773/1607970373.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uncleaned_data['Date'] = pd.to_datetime(uncleaned_data['Date'])
# /tmp/ipykernel_4773/1607970373.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
